# %%
import time
import requests

# %%
requests = ['http://www.googlemaps.com/api/?location=asdf'] * 100

# %%
start_time = time.time()
for req in requests[:10]:
    response = requests.get(req)
end_time = time.time()
# 10s
delta = end_time - start_time

# 60s
time.sleep(max(0, 60 - delta))

# %%
# !kaggle -c submit submission.csv
# Out:
# 01 - Extraction.ipynb 02 - Clase 03.ipynb   flights.db

# %% [markdown]
# ## Kaggle Titanic

# %%
# !pwd
# Out:
# /Users/robert/Documents/repos/IA-Diplomado/Python for Data Science/classes

# %%
# !ls -lhs ../data/titanic
# Out:
# total 184
#   8 -rwxr-xr-x@ 1 robert  staff   3.2K Apr  9  2018 gender_submission.csv
#  56 -rwxr-xr-x@ 1 robert  staff    28K Apr  9  2018 test.csv
# 120 -rwxr-xr-x@ 1 robert  staff    60K Apr  9  2018 train.csv

# %%
import pandas as pd

# %%
# %%time
df = pd.read_csv('../data/titanic/train.csv')
# Out:
# CPU times: user 8.89 ms, sys: 1.75 ms, total: 10.6 ms
# Wall time: 10.2 ms

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df.Sex.mode()
# Out:
# 0    male
# dtype: object

# %%
df.Age.mean()
# Out:
# 29.69911764705882

# %%
df.Age.min()
# Out:
# 0.42

# %%
df['Age'].std()
# Out:
# 14.526497332334044

# %%
df.Age.skew()
# Out:
# 0.38910778230082704

# %%
df.describe(include='all', percentiles=[.05, 0.25, 0.5, 0.75, .95]).T
# Out:
#             count unique                           top freq      mean  \
# PassengerId   891    NaN                           NaN  NaN       446
# Survived      891    NaN                           NaN  NaN  0.383838
# Pclass        891    NaN                           NaN  NaN   2.30864
# Name          891    891  Skoog, Master. Karl Thorsten    1       NaN
# Sex           891      2                          male  577       NaN
# Age           714    NaN                           NaN  NaN   29.6991
# SibSp         891    NaN                           NaN  NaN  0.523008
# Parch         891    NaN                           NaN  NaN  0.381594
# Ticket        891    681                          1601    7       NaN
# Fare          891    NaN                           NaN  NaN   32.2042
# Cabin         204    147                       B96 B98    4       NaN
# Embarked      889      3                             S  644       NaN
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.plot(df.Age)

# %%
df.Age.plot()

# %%
import seaborn as sns

# %%
df.Pclass.head()
# Out:
# 0    3
# 1    1
# 2    3
# 3    1
# 4    3
# Name: Pclass, dtype: int64

# %%
sns.set()

# %%
sns.countplot(df.Pclass);

# %%
sns.countplot(x='Pclass', data=df);

# %%
plt.hist(df.Age.dropna());

# %%
df.Age.hist();

# %%
sns.distplot(df.Age.dropna(), rug=True);
# Out:
# /Users/robert/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.boxplot(x='Age', data=df);

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
sns.boxplot(x='Age', data=df);

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
pd.crosstab(df.Pclass, df.Sex)
# Out:
# Sex     female  male
# Pclass
# 1           94   122
# 2           76   108
# 3          144   347

# %%
pd.cut(df.Age, 10);

# %%
df['AgeDiscrete'] = pd.cut(df.Age, 10)

# %%
pd.crosstab(df.AgeDiscrete, df.Sex)
# Out:
# Sex               female  male
# AgeDiscrete
# (0.34, 8.378]         26    28
# (8.378, 16.336]       23    23
# (16.336, 24.294]      68   109
# (24.294, 32.252]      52   117
# (32.252, 40.21]       44    74
# (40.21, 48.168]       24    46
# (48.168, 56.126]      16    29
# (56.126, 64.084]       8    16
# (64.084, 72.042]       0     9
# (72.042, 80.0]         0     2

# %%
pd.crosstab(df.Survived, df.Sex)
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %%
def foo(x):
    return 2 * x

# %%
foo = lambda x: 2 * x

# %%
lista = [1,2,3,4,5,6]

# %%
sum(lista)
# Out:
# 21

# %%
import numpy as np

# %%
np.sum(lista)
# Out:
# 21

# %%
lista = np.random.randint(0, 100, 10000)

# %%
type(lista)
# Out:
# numpy.ndarray

# %%
len(lista)
# Out:
# 1000

# %%
lista.shape
# Out:
# (1000,)

# %%
# %%timeit
lista.sum()
# Out:
# 7.31 µs ± 164 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
lista2 = list(lista)

# %%
type(lista2)
# Out:
# list

# %%
# %%timeit
sum(lista2)
# Out:
# 486 µs ± 21.8 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
def suma(lista):
    return np.sum(lista)

# %%
pd.crosstab(df.Survived, df.Sex, values=df.Age, aggfunc=np.mean)
# Out:
# Sex          female       male
# Survived
# 0         25.046875  31.618056
# 1         28.847716  27.276022

# %%
pd.crosstab(df.Survived, df.Sex, values=df.Age, aggfunc=np.median)
# Out:
# Sex       female  male
# Survived
# 0           24.5  29.0
# 1           28.0  28.0

# %%
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked       AgeDiscrete
# 0      0         A/5 21171   7.2500   NaN        S  (16.336, 24.294]
# 1      0          PC 17599  71.2833   C85        C   (32.252, 40.21]
# 2      0  STON/O2. 3101282   7.9250   NaN        S  (24.294, 32.252]
# ...

# %%
df2.Sex.head()
# Out:
# 0      male
# 1    female
# 2    female
# 3    female
# 4      male
# Name: Sex, dtype: object

# %%
df2.AgeDiscrete.head()
# Out:
# 0    (16.336, 24.294]
# 1     (32.252, 40.21]
# 2    (24.294, 32.252]
# 3     (32.252, 40.21]
# 4     (32.252, 40.21]
# Name: AgeDiscrete, dtype: category
# Categories (10, interval[float64]): [(0.34, 8.378] < (8.378, 16.336] < (16.336, 24.294] < (24.294, 32.252] ... (48.168, 56.126] < (56.126, 64.084] < (64.084, 72.042] < (72.042, 80.0]]

# %%
df2.AgeDiscrete.cat.codes.head()
# Out:
# 0    2
# 1    4
# 2    3
# 3    4
# 4    4
# dtype: int8

# %%
s = 'Braund, Mr. Owen Harris'
s2 = 'Heikkinen, Miss. Laina'

# %%
'Mr.' in s2
# Out:
# False

# %%
df.Name.head()
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
df.Name.str.contains('Mr').head()
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# Name: Name, dtype: bool

# %%
df2.AgeDiscrete.head()
# Out:
# 0    (16.336, 24.294]
# 1     (32.252, 40.21]
# 2    (24.294, 32.252]
# 3     (32.252, 40.21]
# 4     (32.252, 40.21]
# Name: AgeDiscrete, dtype: category
# Categories (10, interval[float64]): [(0.34, 8.378] < (8.378, 16.336] < (16.336, 24.294] < (24.294, 32.252] ... (48.168, 56.126] < (56.126, 64.084] < (64.084, 72.042] < (72.042, 80.0]]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 714 entries, 0 to 890
# Data columns (total 13 columns):
# PassengerId    714 non-null int64
# Survived       714 non-null int64
# Pclass         714 non-null int64
# Name           714 non-null object
# Sex            714 non-null object
# Age            714 non-null float64
# SibSp          714 non-null int64
# Parch          714 non-null int64
# Ticket         714 non-null object
# Fare           714 non-null float64
# Cabin          185 non-null object
# Embarked       712 non-null object
# AgeDiscrete    714 non-null category
# dtypes: category(1), float64(2), int64(5), object(5)
# memory usage: 73.4+ KB

# %%
d = pd.crosstab(df2.Survived, df2.AgeDiscrete.astype(str)).T

# %%
rows = [
 '(0.34, 8.378]',
 '(8.378, 16.336]',
 '(16.336, 24.294]',
 '(24.294, 32.252]',
 '(32.252, 40.21]',
 '(40.21, 48.168]',
 '(48.168, 56.126]',
 '(56.126, 64.084]',
 '(64.084, 72.042]',
 '(72.042, 80.0]'
]

# %%
rows
# Out:
# ['(0.34, 8.378]',
#  '(8.378, 16.336]',
#  '(16.336, 24.294]',
#  '(24.294, 32.252]',
#  '(32.252, 40.21]',
#  '(40.21, 48.168]',
#  '(48.168, 56.126]',
#  '(56.126, 64.084]',
#  '(64.084, 72.042]',
#  '(72.042, 80.0]']

# %%
sorted(list(d.index))
# Out:
# ['(0.34, 8.378]',
#  '(16.336, 24.294]',
#  '(24.294, 32.252]',
#  '(32.252, 40.21]',
#  '(40.21, 48.168]',
#  '(48.168, 56.126]',
#  '(56.126, 64.084]',
#  '(64.084, 72.042]',
#  '(72.042, 80.0]',
#  '(8.378, 16.336]']

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked       AgeDiscrete
# 0      0         A/5 21171   7.2500   NaN        S  (16.336, 24.294]
# 1      0          PC 17599  71.2833   C85        C   (32.252, 40.21]
# 2      0  STON/O2. 3101282   7.9250   NaN        S  (24.294, 32.252]
# ...

# %%
df[['Sex', 'Age']].head()
# Out:
#       Sex   Age
# 0    male  22.0
# 1  female  38.0
# 2  female  26.0
# 3  female  35.0
# 4    male  35.0

# %%
df.loc[[1, 3, 4]]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch    Ticket     Fare Cabin Embarked      AgeDiscrete
# 1      0  PC 17599  71.2833   C85        C  (32.252, 40.21]
# 3      0    113803  53.1000  C123        S  (32.252, 40.21]
# 4      0    373450   8.0500   NaN        S  (32.252, 40.21]

# %%
cols = [1, 0]
d.loc[rows, cols]
# Out:
# Survived           1    0
# AgeDiscrete
# (0.34, 8.378]     36   18
# (8.378, 16.336]   19   27
# (16.336, 24.294]  63  114
# (24.294, 32.252]  65  104
# (32.252, 40.21]   52   66
# (40.21, 48.168]   24   46
# (48.168, 56.126]  21   24
# (56.126, 64.084]   9   15
# (64.084, 72.042]   0    9
# (72.042, 80.0]     1    1

# %%
df2 = df.dropna(subset=['Age'])

# %%
df2.shape, df.shape
# Out:
# ((714, 13), (891, 13))

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked       AgeDiscrete
# 0      0         A/5 21171   7.2500   NaN        S  (16.336, 24.294]
# 1      0          PC 17599  71.2833   C85        C   (32.252, 40.21]
# 2      0  STON/O2. 3101282   7.9250   NaN        S  (24.294, 32.252]
# ...

# %%
df.groupby('Sex').Age.mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
def mode(x):
    return x.mode()

# %%
df.Pclass.mode()
# Out:
# 0    3
# dtype: int64

# %%
df.groupby(['Sex', 'Pclass']).agg({
    'Age': ['mean', 'min', 'max'],
    'Fare': {'media': np.mean},
    'Pclass': {'moda': lambda x: x.mode()}
})
# Out:
# /Users/robert/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/generic.py:1315: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#                      Age                    Fare Pclass
#                     mean   min   max       media   moda
# Sex    Pclass
# female 1       34.611765  2.00  63.0  106.125798      1
#        2       28.722973  2.00  57.0   21.970121      2
#        3       21.750000  0.75  63.0   16.118810      3
# male   1       41.281386  0.92  80.0   67.226127      1
#        2       30.740707  0.67  70.0   19.741782      2
#        3       26.507589  0.42  74.0   12.661633      3

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
sns.heatmap(df.corr(), cmap='Blues')

# %%
pd.crosstab(df.Survived, df.Sex)
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %%
sns.heatmap(pd.crosstab(df.Survived, df.Sex), cmap='Blues');

# %%
sns.barplot(x='Sex', y='Age', data=df);
# Out:
# /Users/robert/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.pairplot(df.dropna(), hue='Survived');
# Out:
# /Users/robert/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /Users/robert/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /Users/robert/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# /Users/robert/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
# ...

# %%
sns.regplot(df.Age, df.Fare)
# Out:
# /Users/robert/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.lineplot(df.Age, df.Fare)
# Out:
# /Users/robert/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked       AgeDiscrete
# 0      0         A/5 21171   7.2500   NaN        S  (16.336, 24.294]
# 1      0          PC 17599  71.2833   C85        C   (32.252, 40.21]
# 2      0  STON/O2. 3101282   7.9250   NaN        S  (24.294, 32.252]
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# AgeDiscrete    714 non-null category
# dtypes: category(1), float64(2), int64(5), object(5)
# memory usage: 84.6+ KB

# %%
# que filas
df.Age.isnull().head(10)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# 7    False
# 8    False
# 9    False
# Name: Age, dtype: bool

# %%
df[df.Age.isnull()].head()
# Out:
#     PassengerId  Survived  Pclass                           Name     Sex  Age  \
# 5             6         0       3               Moran, Mr. James    male  NaN
# 17           18         1       2   Williams, Mr. Charles Eugene    male  NaN
# 19           20         1       3        Masselmani, Mrs. Fatima  female  NaN
# 26           27         0       3        Emir, Mr. Farred Chehab    male  NaN
# 28           29         1       3  O'Dwyer, Miss. Ellen "Nellie"  female  NaN
#
#     SibSp  Parch  Ticket     Fare Cabin Embarked AgeDiscrete
# 5       0      0  330877   8.4583   NaN        Q         NaN
# 17      0      0  244373  13.0000   NaN        S         NaN
# 19      0      0    2649   7.2250   NaN        C         NaN
# 26      0      0    2631   7.2250   NaN        C         NaN
# 28      0      0  330959   7.8792   NaN        Q         NaN

# %%
# eliminar nulos
df.dropna().shape, df.shape
# Out:
# ((183, 13), (891, 13))

# %%
df.dropna(subset=['Age', 'Parch']).head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked       AgeDiscrete
# 0      0         A/5 21171   7.2500   NaN        S  (16.336, 24.294]
# 1      0          PC 17599  71.2833   C85        C   (32.252, 40.21]
# 2      0  STON/O2. 3101282   7.9250   NaN        S  (24.294, 32.252]
# ...

# %%
# reemplazar nulos

# %%
df.Age.mean()
# Out:
# 29.69911764705882

# %%
df['Age'] = df.Age.fillna(df.Age.mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            891 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# AgeDiscrete    714 non-null category
# dtypes: category(1), float64(2), int64(5), object(5)
# memory usage: 84.6+ KB

# %%
# eliminar columnas

# %%
df2 = df.drop('Cabin', axis=1)

# %%
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked       AgeDiscrete
# 0      0         A/5 21171   7.2500        S  (16.336, 24.294]
# 1      0          PC 17599  71.2833        C   (32.252, 40.21]
# 2      0  STON/O2. 3101282   7.9250        S  (24.294, 32.252]
# ...
